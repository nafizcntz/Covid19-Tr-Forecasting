# %%
import pandas as pd

# %%
df = pd.read_csv("test2.csv")

# %%
df
# Out:
#                   Tarih Toplam Test Sayısı Toplam Vaka Sayısı  \
# 0       22 NİSAN 2021          45.040.704          4.501.382
# 1       21 NİSAN 2021          44.728.595          4.446.591
# 2       20 NİSAN 2021          44.409.756          4.384.624
# 3       19 NİSAN 2021          44.087.628          4.323.596
# 4       18 NİSAN 2021          43.768.759          4.268.447
# ..                  ...                ...                ...
# 403      15 MART 2020                                     18
# 404      14 MART 2020                                      6
# 405      13 MART 2020                                      5
# 406      12 MART 2020                                      1
# 407      11 MART 2020                                      1
#
#     Toplam Vefat Sayısı Hastalarda Zatürre Oranı (%) Ağır Hasta Sayısı  \
# 0               37.329                          2,9             3.463
# 1               36.975                          2,9             3.398
# ...
